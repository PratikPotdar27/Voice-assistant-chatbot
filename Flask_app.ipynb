# %%
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
from flask import render_template
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
import flasgger
from flasgger import Swagger
import os





app=Flask(__name__)
Swagger(app)

app=Flask(__name__)

@app.route('/', methods=["GET","POST"])
def hello():
    if request.method=="POST":
        file =request.files["file"]
        file.save(os.path.join("static",file.filename))
        return render_template('trial.html',message="success")
    return render_template('trial.html',message="upload")
    

from flask import send_file

# ... other code ....


@app.route('/file-downloads/')
def file_downloads():
	try:
		return render_template('downloads.html')
	except Exception as e:
		return str(e)



    
@app.route('/return-files/')
def return_files_tut():
	try:
		return send_file('static/tp1.csv', attachment_filename='tp1.csv')
	except Exception as e:
		return str(e)







if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/Oct/2020 11:50:29] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Oct/2020 11:50:45] "GET /file-downloads/ HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Oct/2020 11:50:45] "GET /file-downloads/c11.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [05/Oct/2020 11:51:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/Oct/2020 11:51:09] "POST / HTTP/1.1" 200 -

# %% [markdown]
# # Use this code

# %%
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
from flask import render_template
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
import flasgger
from flasgger import Swagger
import os
from flask import redirect, url_for




app=Flask(__name__)
Swagger(app)

app=Flask(__name__)

@app.route('/', methods=["GET","POST"])
def hello():
    if request.method=="POST":
        file =request.files["file"]
        file.save(os.path.join("static",file.filename))
        return redirect("file-downloads")
        df_test= pd.read_csv('static/file1.csv')
        xx=df_test['Tweets']
        voc_size=5000
        import nltk
        import re
        from nltk.corpus import stopwords
        from nltk.stem.porter import PorterStemmer
        ps = PorterStemmer()
        corpus = []
        for i in range(0, len(df_test)):
            review = re.sub('[^a-zA-Z]', ' ', df_test['Tweets'][i])
            review = review.lower()
            review = review.split()
            review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
            review = ' '.join(review)
            corpus.append(review)
        from tensorflow.keras.layers import Embedding
        from tensorflow.keras.preprocessing.sequence import pad_sequences
        from tensorflow.keras.models import Sequential
        from tensorflow.keras.preprocessing.text import one_hot
        from tensorflow.keras.layers import LSTM
        from tensorflow.keras.layers import Dense
    
        onehot_repr=[one_hot(words,voc_size)for words in corpus]
    
        sent_length=20
        embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
        import numpy as np
        X_final=np.array(embedded_docs)
        from tensorflow.keras.models import save_model, load_model
        filepath= './saved_model'
        model=load_model(filepath, compile = True)
        predctn= model.predict_classes(X_final)
    
        vv=df_test['Tweets'].count()
    
        gg=np.reshape(predctn,vv)
        gg1=pd.Series(gg)
        new_df=pd.DataFrame(columns=['Tweet','Sentiment'])
        new_df['Tweet']=df_test['Tweets']
        new_df['Sentiment']=gg1
    
        gf=new_df[new_df['Sentiment']==1]
        dd=gf['Sentiment'].count()
    
        gf1=new_df[new_df['Sentiment']==0]
        dd1=gf1['Sentiment'].count()
        new_df.to_csv('final.csv')
        
        
        
        
        
        #return redirect("file-downloads")
    return render_template('trial1.html',message="success")
     
    

from flask import send_file

# ... other code ....


@app.route('/file-downloads/')
def file_downloads():
    return render_template('downloads1.html')
	#except Exception as e:
		#return str(e)



    
@app.route('/return-files/')
def return_files_tut():
    return send_file('/static/c11.jpg')      #static/tp1.csv  ##, attachment_filename='final.csv'
	#except Exception as e:
		#return str(e)







if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Oct/2020 00:26:52] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [07/Oct/2020 00:27:03] "POST / HTTP/1.1" 302 -
# 127.0.0.1 - - [07/Oct/2020 00:27:03] "GET /file-downloads HTTP/1.1" 308 -
# 127.0.0.1 - - [07/Oct/2020 00:27:03] "GET /file-downloads/ HTTP/1.1" 200 -

# %%
f2=pd.read_csv('static/*.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-43-f0545e9a5acd> in <module>
# ----> 1 f2=pd.read_csv('static/*.csv')
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\Anaconda2\envs\tensorflow\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File static/*.csv does not exist: 'static/*.csv'

# %%
f1.head()
# Out:
#    id                                            Tweets
# 0   1  This is a very worst product.Never buy this shit
# 1   2         awsome services. Please buy this its good
# 2   3                          how can I say about this
# 3   4                     Facing problem with my mobile
# 4   5                worst totally worst never buy this

# %%
        df_test= pd.read_csv('static/download2.csv')
        
        xx=df_test['Tweets']
        voc_size=5000
        import nltk
        import re
        from nltk.corpus import stopwords
        from nltk.stem.porter import PorterStemmer
        ps = PorterStemmer()
        corpus = []
        for i in range(0, len(df_test)):
        review = re.sub('[^a-zA-Z]', ' ', df_test['Tweets'][i])
# Out:
#   File "<ipython-input-53-94bd0dff3d96>", line 12
#     review1 = re.sub('[^a-zA-Z]', ' ', df_test['Tweets'][i])
#           ^
# IndentationError: expected an indented block

# %%
df_test= pd.read_csv('static/download2.csv')

# %%
df_test
# Out:
#    id                                            Tweets
# 0   1  This is a very worst product.Never buy this shit
# 1   2         awsome services. Please buy this its good
# 2   3                          how can I say about this
# 3   4                     Facing problem with my mobile
# 4   5                worst totally worst never buy this
# 5   6                                      nice product

# %%
len(df_test)
# Out:
# 6

# %%
from os import listdir

def find_csv_filenames( 'static', suffix=".csv" ):
    filenames = listdir('static')
    return [ filename for filename in filenames if filename.endswith( suffix ) ]
# Out:
#   File "<ipython-input-60-2246d691f348>", line 3
#     def find_csv_filenames( 'static', suffix=".csv" ):
#                                    ^
# SyntaxError: invalid syntax

# %%
import os
import glob

path = 'C:\\Users\DELL\Desktop\deep learning\HTML_Flask\static'
extension = 'csv'
os.chdir(path)
result = glob.glob('*.{}'.format(extension))
print(result)
# Out:
# ['download2.csv', 'timepass.csv']

# %%
import pandas as pd
import glob

path = r'C:\\Users\DELL\Desktop\deep learning\HTML_Flask\static' # use your path
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
frame
# Out:
#        id                                            Tweets   name
# 0       1  This is a very worst product.Never buy this shit     NaN
# 1       2         awsome services. Please buy this its good     NaN
# 2       3                          how can I say about this     NaN
# 3       4                     Facing problem with my mobile     NaN
# 4       5                worst totally worst never buy this     NaN
# 5       6                                      nice product     NaN
# 6  potdar                                               NaN  pratik

# %%
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
from flask import render_template
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
import flasgger
from flasgger import Swagger
import os
from flask import redirect, url_for
import glob



app=Flask(__name__)
Swagger(app)

app=Flask(__name__)

@app.route('/', methods=["GET","POST"])
def hello():
    if request.method=="POST":
        file =request.files["file"]
        file.save(os.path.join("static",file.filename))
        
        path = r'C:\\Users\DELL\Desktop\deep learning\HTML_Flask\static' # use your path
        all_files = glob.glob(path + "/*.csv")

        li = []

        for filename in all_files:
            df = pd.read_csv(filename, index_col=None, header=0)
            li.append(df)

        df_test = pd.concat(li, axis=0, ignore_index=True)
        
        
        
        
        
        
        
        
        
        #df_test= pd.read_csv('static/file1.csv')
        xx=df_test['Tweets']
        voc_size=5000
        import nltk
        import re
        from nltk.corpus import stopwords
        from nltk.stem.porter import PorterStemmer
        ps = PorterStemmer()
        corpus = []
        for i in range(0, len(df_test)):
            review = re.sub('[^a-zA-Z]', ' ', df_test['Tweets'][i])
            review = review.lower()
            review = review.split()
            review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
            review = ' '.join(review)
            corpus.append(review)
        from tensorflow.keras.layers import Embedding
        from tensorflow.keras.preprocessing.sequence import pad_sequences
        from tensorflow.keras.models import Sequential
        from tensorflow.keras.preprocessing.text import one_hot
        from tensorflow.keras.layers import LSTM
        from tensorflow.keras.layers import Dense
    
        onehot_repr=[one_hot(words,voc_size)for words in corpus]
    
        sent_length=20
        embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
        import numpy as np
        X_final=np.array(embedded_docs)
        from tensorflow.keras.models import save_model, load_model
        filepath= './saved_model'
        model=load_model(filepath, compile = True)
        predctn= model.predict_classes(X_final)
    
        vv=df_test['Tweets'].count()
    
        gg=np.reshape(predctn,vv)
        gg1=pd.Series(gg)
        new_df=pd.DataFrame(columns=['Tweet','Sentiment'])
        new_df['Tweet']=df_test['Tweets']
        new_df['Sentiment']=gg1
    
        gf=new_df[new_df['Sentiment']==1]
        dd=gf['Sentiment'].count()
    
        gf1=new_df[new_df['Sentiment']==0]
        dd1=gf1['Sentiment'].count()
        new_df.to_csv('final.csv')
        
        
        
        
        
        return redirect("file-downloads")
    return render_template('trial1.html',message="success")
     
    

from flask import send_file

# ... other code ....


@app.route('/file-downloads/')
def file_downloads():
	try:
		return render_template('downloads.html')
	except Exception as e:
		return str(e)



    
@app.route('/return-files/')
def return_files_tut():
	try:
		return send_file('final.csv', attachment_filename='final.csv')      #static/tp1.csv    #, attachment_filename='final.csv'
	except Exception as e:
		return str(e)







if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Oct/2020 21:34:32] "GET / HTTP/1.1" 200 -

# %%
pip install glob
# Out:
# Collecting glob
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob

# %%
pip install glob2
# Out:
# Collecting glob2
#   Downloading https://files.pythonhosted.org/packages/d7/a5/bbbc3b74a94fbdbd7915e7ad030f16539bfdc1362f7e9003b594f0537950/glob2-0.7.tar.gz
# Building wheels for collected packages: glob2
#   Building wheel for glob2 (setup.py): started
#   Building wheel for glob2 (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\DELL\AppData\Local\pip\Cache\wheels\a9\54\c2\a73022629500264586ce9d41046f44d681a369d4273c97eb12
# Successfully built glob2
# Installing collected packages: glob2
# Successfully installed glob2-0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from werkzeug.utils import secure_filename
from flask import Flask,flash,request,redirect,send_file,render_template
UPLOAD_FOLDER = 'static/'
#app = Flask(__name__)
app = Flask(__name__, template_folder='templates')
app.config['UPLOAD_FOLDER'] = UPLOAD_FOLDER
# Upload API
@app.route('/uploadfile', methods=['GET', 'POST'])
def upload_file():
    if request.method == 'POST':
        # check if the post request has the file part
        if 'file' not in request.files:
            print('no file')
            return redirect(request.url)
        file = request.files['file']
        # if user does not select file, browser also
        # submit a empty part without filename
        if file.filename == '':
            print('no filename')
            return redirect(request.url)
        else:
            filename = secure_filename(file.filename)
            file.save(os.path.join(app.config['UPLOAD_FOLDER'], filename))
            print("saved file successfully")
      #send file name as parameter to downlad
            return redirect('/downloadfile/'+ filename)
    return render_template('upload_file.html')
# Download API
@app.route("/downloadfile/<filename>", methods = ['GET'])
def download_file(filename):
    return render_template('chrome.html',value=filename)
@app.route('/return-files/<filename>')
def return_files_tut(filename):
    file_path = UPLOAD_FOLDER + filename
    return send_file(file_path, as_attachment=True, attachment_filename='')
if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [07/Oct/2020 21:52:54] "GET / HTTP/1.1" 404 -
# [2020-10-07 21:53:08,105] ERROR in app: Exception on /uploadfile [GET]
# Traceback (most recent call last):
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-23-1dc448ed6469>", line 28, in upload_file
#     return render_template('upload_file.html')
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\flask\templating.py", line 138, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\jinja2\environment.py", line 869, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\jinja2\environment.py", line 830, in get_template
#     return self._load_template(name, self.make_globals(globals))
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\jinja2\environment.py", line 804, in _load_template
#     template = self.loader.load(self, name, globals)
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\jinja2\loaders.py", line 113, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\flask\templating.py", line 60, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\DELL\Anaconda2\envs\tensorflow\lib\site-packages\flask\templating.py", line 89, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: upload_file.html
# 127.0.0.1 - - [07/Oct/2020 21:53:08] "GET /uploadfile HTTP/1.1" 500 -

# %%
from flask import Flask, send_file, render_template
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
from flask import render_template
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
import flasgger
from flasgger import Swagger
import os
from flask import redirect, url_for
import glob










app=Flask(__name__)

@app.route('/', methods=["GET","POST"])
def hello():
    if request.method=="POST":
        file =request.files["file"]
        file.save(os.path.join("static",file.filename))
        
        path = r'C:\\Users\DELL\Desktop\deep learning\HTML_Flask\static' # use your path
        all_files = glob.glob(path + "/*.csv")

        li = []

        for filename in all_files:
            df = pd.read_csv(filename, index_col=None, header=0)
            li.append(df)

        df_test = pd.concat(li, axis=0, ignore_index=True)
        
        
        
        
        
        
        
        
        
        #df_test= pd.read_csv('static/file1.csv')
        xx=df_test['Tweets']
        voc_size=5000
        import nltk
        import re
        from nltk.corpus import stopwords
        from nltk.stem.porter import PorterStemmer
        ps = PorterStemmer()
        corpus = []
        for i in range(0, len(df_test)):
            review = re.sub('[^a-zA-Z]', ' ', df_test['Tweets'][i])
            review = review.lower()
            review = review.split()
            review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
            review = ' '.join(review)
            corpus.append(review)
        from tensorflow.keras.layers import Embedding
        from tensorflow.keras.preprocessing.sequence import pad_sequences
        from tensorflow.keras.models import Sequential
        from tensorflow.keras.preprocessing.text import one_hot
        from tensorflow.keras.layers import LSTM
        from tensorflow.keras.layers import Dense
    
        onehot_repr=[one_hot(words,voc_size)for words in corpus]
    
        sent_length=20
        embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
        import numpy as np
        X_final=np.array(embedded_docs)
        from tensorflow.keras.models import save_model, load_model
        filepath= './saved_model'
        model=load_model(filepath, compile = True)
        predctn= model.predict_classes(X_final)
    
        vv=df_test['Tweets'].count()
    
        gg=np.reshape(predctn,vv)
        gg1=pd.Series(gg)
        new_df=pd.DataFrame(columns=['Tweet','Sentiment'])
        new_df['Tweet']=df_test['Tweets']
        new_df['Sentiment']=gg1
    
        gf=new_df[new_df['Sentiment']==1]
        dd=gf['Sentiment'].count()
    
        gf1=new_df[new_df['Sentiment']==0]
        dd1=gf1['Sentiment'].count()
        
        dire=os.path.dirname(os.path.abspath('sen.py'))
        
        new_df.to_csv(os.path.join(dire,'final_today.csv'))
        
        
        
        
        
        return redirect("p1")
    return render_template('trial1.html',message="success")

























@app.route('/p1')
def upload_form1():
    return render_template('p.html')

@app.route('/download1')
def download_file1():
    path="final_today.csv"
    return send_file(path, as_attachment=True)

if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [12/Oct/2020 19:30:22] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Oct/2020 19:30:44] "POST / HTTP/1.1" 302 -
# 127.0.0.1 - - [12/Oct/2020 19:30:44] "GET /p1 HTTP/1.1" 200 -
# 127.0.0.1 - - [12/Oct/2020 19:30:48] "GET /download1 HTTP/1.1" 200 -

# %%
import app

# %%
import tensorflow

# %%
from flask import Flask, send_file, render_template
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
from flask import render_template
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
import flasgger
from flasgger import Swagger
import os
from flask import redirect, url_for
import glob










app=Flask(__name__)

@app.route('/', methods=["GET","POST"])
def hello():
    if request.method=="POST":
        file =request.files["file"]
        file.save(os.path.join("static",file.filename))
        
        return redirect("p1")
        path = r'C:\\Users\DELL\Desktop\deep learning\HTML_Flask\static' # use your path
        all_files = glob.glob(path + "/*.csv")

        li = []

        for filename in all_files:
            df = pd.read_csv(filename, index_col=None, header=0)
            li.append(df)

        df_test = pd.concat(li, axis=0, ignore_index=True)
        
        
        
        
        
        
        
        
        
        #df_test= pd.read_csv('static/file1.csv')
        xx=df_test['Tweets']
        voc_size=5000
        import nltk
        import re
        from nltk.corpus import stopwords
        from nltk.stem.porter import PorterStemmer
        ps = PorterStemmer()
        corpus = []
        for i in range(0, len(df_test)):
            review = re.sub('[^a-zA-Z]', ' ', df_test['Tweets'][i])
            review = review.lower()
            review = review.split()
            review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
            review = ' '.join(review)
            corpus.append(review)
        from tensorflow.keras.layers import Embedding
        from tensorflow.keras.preprocessing.sequence import pad_sequences
        from tensorflow.keras.models import Sequential
        from tensorflow.keras.preprocessing.text import one_hot
        from tensorflow.keras.layers import LSTM
        from tensorflow.keras.layers import Dense
    
        onehot_repr=[one_hot(words,voc_size)for words in corpus]
    
        sent_length=20
        embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
        import numpy as np
        X_final=np.array(embedded_docs)
        from tensorflow.keras.models import save_model, load_model
        filepath= './saved_model'
        model=load_model(filepath, compile = True)
        predctn= model.predict_classes(X_final)
    
        vv=df_test['Tweets'].count()
    
        gg=np.reshape(predctn,vv)
        gg1=pd.Series(gg)
        new_df=pd.DataFrame(columns=['Tweet','Sentiment'])
        new_df['Tweet']=df_test['Tweets']
        new_df['Sentiment']=gg1
    
        gf=new_df[new_df['Sentiment']==1]
        dd=gf['Sentiment'].count()
    
        gf1=new_df[new_df['Sentiment']==0]
        dd1=gf1['Sentiment'].count()
        new_df.to_csv('C:\\Users\DELL\Desktop\deep learning\HTML_Flask\send\final.csv')
        
        
        
        
        
        
    return render_template('trial1.html',message="success")

























@app.route('/p1')
def upload_form1():
    return render_template('p.html')

@app.route('/download1')
def download_file1():
    path="final.csv"
    return send_file(path, as_attachment=True)

if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [11/Oct/2020 09:39:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Oct/2020 09:40:12] "POST / HTTP/1.1" 302 -
# 127.0.0.1 - - [11/Oct/2020 09:40:12] "GET /p1 HTTP/1.1" 200 -

# %%
from io import StringIO

# %%
from flask import Flask, send_file, render_template
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
from flask import render_template
from flask import Flask, request
import numpy as np
#import pickle
import pandas as pd
import flasgger
from flasgger import Swagger
import os
from flask import redirect, url_for
import glob


app=Flask(__name__)

@app.route('/', methods=["GET","POST"])
@app.route('/')
def home():
    #return 'Hello World'
    return render_template('p.html')


@app.route('/p1')
def upload_form1():
    return render_template('p.html')

@app.route('/download1')
def download_file1():
    path="final.csv"
    return send_file(path, as_attachment=True)

if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [18/Nov/2020 19:47:48] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Nov/2020 19:48:03] "GET /download1 HTTP/1.1" 200 -
# 127.0.0.1 - - [18/Nov/2020 19:48:03] "GET /download1 HTTP/1.1" 200 -
